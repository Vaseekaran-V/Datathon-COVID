# %%
import pandas as pd

# %%
df = pd.read_json('response.json')

# %%
df.head()
# Out:
#                         success  message  \
# daily_pcr_testing_data     True  Success
# global_deaths              True  Success
# global_new_cases           True  Success
# global_new_deaths          True  Success
# global_recovered           True  Success
#
#                                                                      data
# daily_pcr_testing_data  [{'date': '2020-02-18', 'count': '1'}, {'date'...
# global_deaths                                                     1179974
# global_new_cases                                                   504412
# global_new_deaths                                                    7106
# global_recovered                                                 32761004

# %%
df.head(100)
# Out:
#                                                 success  message  \
# daily_pcr_testing_data                             True  Success
# global_deaths                                      True  Success
# global_new_cases                                   True  Success
# global_new_deaths                                  True  Success
# global_recovered                                   True  Success
# global_total_cases                                 True  Success
# hospital_data                                      True  Success
# local_active_cases                                 True  Success
# local_deaths                                       True  Success
# local_new_cases                                    True  Success
# local_new_deaths                                   True  Success
# local_recovered                                    True  Success
# local_total_cases                                  True  Success
# ...

# %%
df['data'][0]
# Out:
# [{'date': '2020-02-18', 'count': '1'},
#  {'date': '2020-02-19', 'count': '0'},
#  {'date': '2020-02-20', 'count': '1'},
#  {'date': '2020-02-21', 'count': '0'},
#  {'date': '2020-02-22', 'count': '0'},
#  {'date': '2020-02-23', 'count': '0'},
#  {'date': '2020-02-24', 'count': '0'},
#  {'date': '2020-02-25', 'count': '0'},
#  {'date': '2020-02-26', 'count': '2'},
#  {'date': '2020-02-27', 'count': '2'},
#  {'date': '2020-02-28', 'count': '5'},
#  {'date': '2020-02-29', 'count': '3'},
#  {'date': '2020-03-01', 'count': '1'},
#  {'date': '2020-03-02', 'count': '10'},
#  {'date': '2020-03-03', 'count': '6'},
#  {'date': '2020-03-04', 'count': '9'},
#  {'date': '2020-03-05', 'count': '1'},
#  {'date': '2020-03-06', 'count': '4'},
#  {'date': '2020-03-07', 'count': '7'},
#  {'date': '2020-03-08', 'count': '3'},
#  {'date': '2020-03-09', 'count': '1'},
#  {'date': '2020-03-10', 'count': '12'},
#  {'date': '2020-03-11', 'count': '10'},
#  {'date': '2020-03-12', 'count': '17'},
# ...

# %%
df_count = pd.read_json(df['data'][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-3bac290da9a5> in <module>
# ----> 1 df_count = pd.read_json(df['data'][0])
#
# /opt/anaconda3/envs/hello/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# /opt/anaconda3/envs/hello/lib/python3.6/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     583     compression = infer_compression(path_or_buf, compression)
#     584     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# ...
